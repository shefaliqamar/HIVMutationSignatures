# %%
from sigproextractor import sigpro as sig

# %% [markdown]
# # Running the example
#
# Now we are going to execute the code using the csvsample.csv file

# %%
sig.sigProfilerExtractor("csv", "FirstSigs", "data/DNAStyleFrequencies.csv", totalIterations=5, gpu=False)
# Out:
# ************** Reported Current Memory Use: 0.64 GB *****************
#
# Normalization Cutoff is : 75
# Extracting signature 1 for mutation type 96
# process 1 continues please wait...
# execution time: 0 seconds
# process 1 continues please wait...
#
# execution time: 0 seconds
# process 1 continues please wait...
#
# execution time: 0 seconds
#
# process 1 continues please wait...
# process 1 continues please wait...
# execution time: 0 seconds
# execution time: 0 seconds
#
#
# Time taken to collect 5 iterations for 1 signatures is 0.33 seconds
# Optimization time is 0.15107488632202148 seconds
# The reconstruction error is 0.3996, average process stability is 1.0 and
# the minimum process stability is 1.0 for 1 signatures
#
#
# Extracting signature 2 for mutation type 96
# process 2 continues please wait...
# execution time: 0 seconds
#
# process 2 continues please wait...
# process 2 continues please wait...
# execution time: 0 seconds
# execution time: 0 seconds
#
#
# process 2 continues please wait...
# execution time: 0 seconds
#
# process 2 continues please wait...
# execution time: 0 seconds
#
# Time taken to collect 5 iterations for 2 signatures is 0.43 seconds
# Optimization time is 0.1759812831878662 seconds
# The reconstruction error is 0.3363, average process stability is 0.92 and
# the minimum process stability is 0.92 for 2 signatures
#
#
# Extracting signature 3 for mutation type 96
# process 3 continues please wait...
# execution time: 0 seconds
#
# process 3 continues please wait...
# execution time: 0 seconds
#
# process 3 continues please wait...
# execution time: 0 seconds
#
# process 3 continues please wait...
# execution time: 0 seconds
#
# process 3 continues please wait...
# execution time: 1 seconds
#
# Time taken to collect 5 iterations for 3 signatures is 0.74 seconds
# Optimization time is 0.13886046409606934 seconds
# The reconstruction error is 0.323, average process stability is 0.65 and
# the minimum process stability is 0.47 for 3 signatures
#
#
# Extracting signature 4 for mutation type 96
# process 4 continues please wait...
# execution time: 0 seconds
#
# process 4 continues please wait...
# execution time: 0 seconds
#
# process 4 continues please wait...
# execution time: 0 seconds
#
# process 4 continues please wait...
# execution time: 0 seconds
#
# process 4 continues please wait...
# execution time: 0 seconds
#
# Time taken to collect 5 iterations for 4 signatures is 0.65 seconds
# Optimization time is 0.1775529384613037 seconds
# The reconstruction error is 0.2917, average process stability is 0.59 and
# the minimum process stability is 0.0 for 4 signatures
#
#
# Extracting signature 5 for mutation type 96
# process 5 continues please wait...
# execution time: 0 seconds
#
# process 5 continues please wait...
# execution time: 0 seconds
#
# process 5 continues please wait...
# execution time: 0 seconds
#
# process 5 continues please wait...
# execution time: 0 seconds
#
# process 5 continues please wait...
# execution time: 0 seconds
#
# Time taken to collect 5 iterations for 5 signatures is 0.64 seconds
# Optimization time is 0.1439650058746338 seconds
# The reconstruction error is 0.2972, average process stability is 0.4 and
# the minimum process stability is -0.29 for 5 signatures
#
#
# Extracting signature 6 for mutation type 96
# process 6 continues please wait...
# execution time: 0 seconds
#
# process 6 continues please wait...
# execution time: 0 seconds
#
# process 6 continues please wait...
# execution time: 0 seconds
#
# process 6 continues please wait...
# execution time: 1 seconds
#
# process 6 continues please wait...
# execution time: 1 seconds
#
# Time taken to collect 5 iterations for 6 signatures is 1.02 seconds
# Optimization time is 0.16472887992858887 seconds
# The reconstruction error is 0.283, average process stability is 0.3 and
# the minimum process stability is -0.24 for 6 signatures
#
#
# Extracting signature 7 for mutation type 96
# process 7 continues please wait...
# execution time: 0 seconds
#
# process 7 continues please wait...
# execution time: 0 seconds
#
# process 7 continues please wait...
# execution time: 1 seconds
#
# process 7 continues please wait...
# execution time: 1 seconds
#
# process 7 continues please wait...
# execution time: 1 seconds
#
# Time taken to collect 5 iterations for 7 signatures is 0.92 seconds
# Optimization time is 0.1387650966644287 seconds
# The reconstruction error is 0.2756, average process stability is 0.2 and
# the minimum process stability is -0.3 for 7 signatures
#
#
# Extracting signature 8 for mutation type 96
# process 8 continues please wait...
# execution time: 0 seconds
#
# process 8 continues please wait...
# execution time: 0 seconds
#
# process 8 continues please wait...
# execution time: 1 seconds
#
# process 8 continues please wait...
# execution time: 1 seconds
#
# process 8 continues please wait...
# execution time: 1 seconds
#
# Time taken to collect 5 iterations for 8 signatures is 1.13 seconds
# Optimization time is 0.1221776008605957 seconds
# The reconstruction error is 0.2658, average process stability is 0.25 and
# the minimum process stability is -0.3 for 8 signatures
#
#
# Extracting signature 9 for mutation type 96
# process 9 continues please wait...
# execution time: 1 seconds
#
# process 9 continues please wait...
# execution time: 1 seconds
#
# process 9 continues please wait...
# execution time: 1 seconds
#
# process 9 continues please wait...
# execution time: 1 seconds
#
# process 9 continues please wait...
# execution time: 1 seconds
#
# Time taken to collect 5 iterations for 9 signatures is 1.63 seconds
# Optimization time is 0.12250900268554688 seconds
# The reconstruction error is 0.2615, average process stability is 0.2 and
# the minimum process stability is -0.2 for 9 signatures
#
#
# Extracting signature 10 for mutation type 96
# process 10 continues please wait...
# execution time: 1 seconds
#
# process 10 continues please wait...
# execution time: 1 seconds
#
# process 10 continues please wait...
# execution time: 1 seconds
#
# process 10 continues please wait...
# execution time: 2 seconds
#
# process 10 continues please wait...
# execution time: 3 seconds
#
# Time taken to collect 5 iterations for 10 signatures is 3.34 seconds
# Optimization time is 0.12082839012145996 seconds
# The reconstruction error is 0.2591, average process stability is 0.18 and
# the minimum process stability is -0.22 for 10 signatures
#
#
#
#
#
# Your Job Is Successfully Completed! Thank You For Using SigProfiler Extractor.
