# %%
from sigproextractor import sigpro as sig

# %%
# path_to_example_table = sig.importdata("data/csvexample.csv")

# %%
data = path_to_example_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7371ab5fceef> in <module>
# ----> 1 data = path_to_example_table
#
# NameError: name 'path_to_example_table' is not defined

# %% [markdown]
# # Running the example
#
# Now we are going to execute the code using the csvsample.csv file

# %%
sig.sigProfilerExtractor("csv", "Laplace_k=0.3_output", "data/Laplace_k=0.3.csv")
# Out:
# ************** Reported Current Memory Use: 0.16 GB *****************
#
# Normalization Cutoff is : 996
# Extracting signature 1 for mutation type 96
# process 1 continues please wait...
# execution time: 2 seconds
#
# process 1 continues please wait...
# execution time: 2 seconds
#
# process 1 continues please wait...
# execution time: 2 seconds
#
# process 1 continues please wait...
# execution time: 2 seconds
#
# process 1 continues please wait...
# process 1 continues please wait...
# execution time: 2 seconds
# execution time: 2 seconds
#
#
# process 1 continues please wait...
# execution time: 3 seconds
#
# process 1 continues please wait...
# execution time: 3 seconds
#
# Time taken to collect 8 iterations for 1 signatures is 2.66 seconds
# Optimization time is 2.6027469635009766 seconds
# The reconstruction error is 0.2752, average process stability is 1.0 and
# the minimum process stability is 1.0 for 1 signatures
# ...
